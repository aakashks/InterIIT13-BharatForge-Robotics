# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np


class ScanningEnvironment(gym.Env):
    """
    Custom Environment for managing robot scanning tasks
    """

    def __init__(self, grid_size=(10, 10), num_robots=5, max_steps=100):
        super(ScanningEnvironment, self).__init__()

        self.grid_size = grid_size
        self.num_robots = num_robots
        self.max_steps = max_steps
        self.current_steps = 0

        # Action space: Each robot chooses a grid cell to visit
        self.action_space = spaces.MultiDiscrete(
            [grid_size[0] * grid_size[1]] * num_robots
        )

        # Observation space
        self.observation_space = spaces.Dict(
            {
                "grid": spaces.Box(
                    low=0, high=np.inf, shape=grid_size, dtype=np.float32
                ),
                "robot_positions": spaces.MultiDiscrete(
                    [grid_size[0] * grid_size[1]] * num_robots
                ),
            }
        )

        self.reset()

    def reset(self, seed=None, options=None):
        """
        Reset the environment to its initial state
        """
        super().reset(seed=seed)  # Properly seed the environment
        self.grid = np.zeros(self.grid_size)  # Tracks the coverage of each grid cell
        self.robot_positions = np.random.choice(
            self.grid_size[0] * self.grid_size[1], self.num_robots, replace=False
        )
        self.current_steps = 0
        return self._get_obs(), {}

    def step(self, actions):
        """
        Take a step in the environment based on the robots' assigned target locations
        """
        rewards = 0

        # Update positions and coverage
        for i, target in enumerate(actions):
            x, y = divmod(target, self.grid_size[1])
            self.grid[x, y] += 1  # Increment visit count
            rewards += 1 / (
                1 + self.grid[x, y]
            )  # Reward is higher for less-visited areas
            self.robot_positions[i] = target

        self.current_steps += 1
        done = self.current_steps >= self.max_steps
        return self._get_obs(), rewards, done, False, {}

    def _get_obs(self):
        """
        Return the current state of the environment
        """
        return {
            "grid": self.grid.copy(),
            "robot_positions": self.robot_positions.copy(),
        }

    def render(self):
        """
        Render the environment state for debugging
        """
        print("Grid Coverage:")
        print(self.grid)
        print("Robot Positions:", self.robot_positions)


# Example RL Agent for Testing
class RandomAgent:
    def __init__(self, env):
        self.env = env

    def act(self):
        """
        Choose random target locations for robots
        """
        return self.env.action_space.sample()

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env

env = ScanningEnvironment(grid_size=(10, 10), num_robots=5, max_steps=50)
# Check if the custom environment is valid
check_env(env)

# Train the RL agent
model = PPO("MultiInputPolicy", env, verbose=1)
model.learn(total_timesteps=10000)

# Test the trained agent
obs = env.reset()
for _ in range(50):
    action, _ = model.predict(obs)
    obs, reward, done, _ = env.step(action)
    env.render()
    if done:
        break
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/stable_baselines3/common/env_checker.py:296, in _check_returned_values(env, observation_space, action_space)
#     295 try:
# --> 296     _check_obs(obs[key], observation_space.spaces[key], "reset")
#     297 except AssertionError as e:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/stable_baselines3/common/env_checker.py:219, in _check_obs(obs, observation_space, method_name)
#     214 assert observation_space.shape == obs.shape, (
#     215     f"The observation returned by the `{method_name}()` method does not match the shape "
#     216     f"of the given observation space {observation_space}. "
#     217     f"Expected: {observation_space.shape}, actual shape: {obs.shape}"
#     218 )
# --> 219 assert np.can_cast(obs.dtype, observation_space.dtype), (
#     220     f"The observation returned by the `{method_name}()` method does not match the data type (cannot cast) "
#     221     f"of the given observation space {observation_space}. "
#     222     f"Expected: {observation_space.dtype}, actual dtype: {obs.dtype}"
#     223 )
#     224 if isinstance(observation_space, spaces.Box):
#
# AssertionError: The observation returned by the `reset()` method does not match the data type (cannot cast) of the given observation space Box(0.0, inf, (10, 10), float32). Expected: float32, actual dtype: float64
#
# The above exception was the direct cause of the following exception:
#
# AssertionError                            Traceback (most recent call last)
# Cell In[17], line 6
#       4 env = ScanningEnvironment(grid_size=(10, 10), num_robots=5, max_steps=50)
#       5 # Check if the custom environment is valid
# ----> 6 check_env(env)
#       8 # Train the RL agent
#       9 model = PPO("MultiInputPolicy", env, verbose=1)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/stable_baselines3/common/env_checker.py:473, in check_env(env, warn, skip_render_check)
#     470     return
#     472 # ============ Check the returned values ===============
# --> 473 _check_returned_values(env, observation_space, action_space)
#     475 # ==== Check the render method and the declared render modes ====
#     476 if not skip_render_check:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/py312/lib/python3.12/site-packages/stable_baselines3/common/env_checker.py:298, in _check_returned_values(env, observation_space, action_space)
#     296             _check_obs(obs[key], observation_space.spaces[key], "reset")
#     297         except AssertionError as e:
# --> 298             raise AssertionError(f"Error while checking key={key}: " + str(e)) from e
#     299 else:
#     300     _check_obs(obs, observation_space, "reset")
#
# AssertionError: Error while checking key=grid: The observation returned by the `reset()` method does not match the data type (cannot cast) of the given observation space Box(0.0, inf, (10, 10), float32). Expected: float32, actual dtype: float64
